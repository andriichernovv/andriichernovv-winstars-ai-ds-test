# %%
import pandas as pd
import numpy as np

from src.data.mnist_loader import load_mnist
from src.factory.mnist_classifier import MnistClassifier

# %%
x_train, y_train, x_test, y_test = load_mnist()
# Out:
# 2026-03-18 03:23:36,980 | INFO | src.data.mnist_loader | Starting MNIST dataset loading.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# 2026-03-18 03:23:40,608 | INFO | src.data.mnist_loader | MNIST dataset loaded successfully.
# 2026-03-18 03:23:40,649 | INFO | src.data.mnist_loader | x_train shape: (60000, 28, 28)
# 2026-03-18 03:23:40,652 | INFO | src.data.mnist_loader | y_train shape: (60000,)
# 2026-03-18 03:23:40,655 | INFO | src.data.mnist_loader | x_test shape: (10000, 28, 28)
# 2026-03-18 03:23:40,658 | INFO | src.data.mnist_loader | y_test shape: (10000,)
# 2026-03-18 03:23:41,367 | INFO | src.data.mnist_loader | Input images converted to float32.
# 2026-03-18 03:23:41,711 | INFO | src.data.mnist_loader | Input images normalized to the [0, 1] range.
# 2026-03-18 03:23:41,716 | INFO | src.data.mnist_loader | Labels converted to int64.
# 2026-03-18 03:23:41,718 | INFO | src.data.mnist_loader | MNIST preprocessing completed successfully.

# %%
rf = MnistClassifier("rf")
# Out:
# 2026-03-18 03:23:41,869 | INFO | src.factory.mnist_classifier | Initializing MnistClassifier with algorithm='rf'
# 2026-03-18 03:23:41,899 | INFO | src.models.rf_classifier | Initializing RandomForestMnistClassifier with n_estimators=100, random_state=42, max_depth=None
# 2026-03-18 03:23:41,914 | INFO | src.factory.mnist_classifier | Model RandomForestMnistClassifier created.

# %%
rf.train(x_train=x_train, y_train=y_train)
# Out:
# 2026-03-18 03:23:42,200 | INFO | src.factory.mnist_classifier | Starting training pipeline.
# 2026-03-18 03:23:42,235 | INFO | src.factory.mnist_classifier | Preparing input data. Original shape: (60000, 28, 28)
# 2026-03-18 03:23:42,262 | INFO | src.data.mnist_loader | Flattening images. Input shape: (60000, 28, 28)
# 2026-03-18 03:23:42,267 | INFO | src.data.mnist_loader | Flattening completed. Output shape: (60000, 784)
# 2026-03-18 03:23:42,308 | INFO | src.factory.mnist_classifier | Data flattened. New shape: (60000, 784)
# 2026-03-18 03:23:42,330 | INFO | src.models.rf_classifier | Starting Random Forest training. x_train shape: (60000, 784), y_train shape: (60000,)
# 2026-03-18 03:25:00,870 | INFO | src.models.rf_classifier | Random Forest training completed successfully.
# 2026-03-18 03:25:00,899 | INFO | src.factory.mnist_classifier | Training pipeline completed.

# %%
rf.predict(x_train)
# Out:
# 2026-03-18 03:25:49,967 | INFO | src.factory.mnist_classifier | Starting prediction pipeline.
# 2026-03-18 03:25:49,970 | INFO | src.factory.mnist_classifier | Preparing input data. Original shape: (60000, 28, 28)
# 2026-03-18 03:25:49,973 | INFO | src.data.mnist_loader | Flattening images. Input shape: (60000, 28, 28)
# 2026-03-18 03:25:49,975 | INFO | src.data.mnist_loader | Flattening completed. Output shape: (60000, 784)
# 2026-03-18 03:25:49,977 | INFO | src.factory.mnist_classifier | Data flattened. New shape: (60000, 784)
# 2026-03-18 03:25:49,980 | INFO | src.models.rf_classifier | Starting Random Forest inference. Input shape: (60000, 784)
# 2026-03-18 03:25:56,478 | INFO | src.models.rf_classifier | Random Forest inference completed successfully. Output shape: (60000,)
# 2026-03-18 03:25:56,482 | INFO | src.factory.mnist_classifier | Prediction pipeline completed.
# array([5, 0, 4, ..., 5, 6, 8], shape=(60000,))
